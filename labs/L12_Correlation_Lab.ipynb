# %% [markdown]
# # L12 Lab: Correlation & Multicollinearity
#
# **Goal:** Pearson and Spearman correlation; interpret redundancy.
#
# **Dataset:** `../datasets/sample_sales.csv` or `pima_diabetes.csv`

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../datasets/sample_sales.csv")
num = df.select_dtypes("number")
print("Pearson:\n", num.corr(method="pearson").round(3))
print("\nSpearman:\n", num.corr(method="spearman").round(3))

# %%
import matplotlib.pyplot as plt
corr = num.corr()
plt.figure(figsize=(6, 5))
plt.imshow(corr, cmap="RdBu_r", vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr)), corr.columns)
plt.title("Pearson correlation")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercises
# 1. Find strongest positive and strongest negative pair.
# 2. When is Spearman preferred over Pearson?
# 3. Which pair would you avoid as joint predictors and why?
